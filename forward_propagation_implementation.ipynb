# %% [markdown]
# <a href="https://colab.research.google.com/github/joel0codes0ml/MACHINE-LEARNING-PROJECTS/blob/implementation-algorithms/forward_propagation_implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# create a sample dataset

# %%
data = {
    'cgpa': [8.5, 9.2, 7.8], 'profile_score': [85, 92, 78], 'lpa': [10, 12, 8]}
df = pd.DataFrame(data)
X = df[['cgpa', 'profile_score']].values

# %% [markdown]
# initialze parameters

# %%
def initialize_parameters():
  np.random.seed(1)
  W = np.random.randn(2, 1) * 0.01
  b = np.zeros((1, 1))
  return W, b

# %% [markdown]
# forward propagation

# %%
def forward_propagation(X, W, b):
  Z = np.dot(X, W) + b
  A = 1 / (1 + np.exp(-Z))
  return A

# %% [markdown]
# execute forward propagation

# %%
W, b = initialize_parameters()
A = forward_propagation(X, W, b)
print("Final Output:", A)
# Out:
# Final Output: [[0.40566303]
#  [0.39810287]
#  [0.41326819]]
