# %% [markdown]
# <a href="https://colab.research.google.com/github/joel0codes0ml/MACHINE-LEARNING-PROJECTS/blob/main/Music_recommendation_system_with_Machine_Learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# importing the libraries and dataset

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/content/tcc_ceds_music.csv')
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1408814299.py in <cell line: 0>()
# ----> 1 data = pd.read_csv('/content/tcc_ceds_music.csv')
#       2 data.head()
#
# NameError: name 'pd' is not defined

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='genre', data=data, order=data['genre'].value_counts().index[:10])
plt.title('Top 10 Genres')
plt.xlabel('Count')
plt.ylabel('Genre')
plt.show()

# %%
top_artists = data.groupby('artist_name').size().sort_values(ascending=False).head(10)
plt.figure(figsize=(10, 6))
sns.barplot(x=top_artists.values, y=top_artists.index, palette='viridis')
plt.title('Top 10 Artists by Number of Songs')
plt.xlabel('Number of songs')
plt.ylabel('Artist Name')
plt.show()

# %% [markdown]
# preprocessing the data

# %%
data['combined_features'] = (
    data['genre'].fillna('') + ' ' +
    data['artist_name'].fillna('') + ' ' +
    data['track_name'].fillna('')
)

# %% [markdown]
# tf-idf vectorization

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_traansform(data['combined_features'])

# %% [markdown]
# song similarity

# %%
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)
def get_reccommendations(song_ttle, data, cosine_sim, top_n=10):
  idx = data[data['track_name'].str.lower() == song_title.lower()].index
  if len(idx) == 0:
    print(f"Song '{song_title}' not found in the dataset.")
    return pd.DataFrame()
  idx = idx[0]

# %% [markdown]
# getting the similarity scores

# %%
sim_scores = list(enumerate(cosine_sim[idx]))
sim_scores = sorted(sim_scores, key=lambda x: X[1], reverse=True)
#skip the first song get top n
sim_scores = sim_scores[1:top_n+1]
song_indices = [i[0] for i in sim_scores]
#select the songs at indices we found
return data.iloc[song_indicesg]
return recommendations

# %% [markdown]
# generate recommendations

# %%
recommended_songs = get_recommendations('cry', data, cosine_sim, top_n=10)
if not recommended_songs.empty:
  print(recommended_songs[['track_name', 'artist_name', 'genre']])

# %% [markdown]
# visualization

# %%
plt.figure(figsize=(10, 6))
sns.barplot(y='track_name', x='artist_name', data=recommended_songd, palette='coolwarm')
plt.title('Recommended Songs Similar to cry')
plt.xlabel("Artist Name")
plt.ylabel('Song Name')
plt.show()
